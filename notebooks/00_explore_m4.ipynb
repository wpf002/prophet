# %% [markdown]
# # 00 — Explore M4 dataset
#
# Initial exploration of the M4 competition dataset. Run after `make download-m4`.
#
# **Notebooks are exploratory only — production logic lives in `src/prophet/`.**

# %%
import polars as pl
from prophet.config import settings
from prophet.data.loaders import M4Frequency, load_m4

train, test = load_m4(M4Frequency.HOURLY, settings.data_raw, sample_n=10)
train.head()
